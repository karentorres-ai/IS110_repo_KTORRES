# %% [markdown]
# CHAPTER 5

# %% [markdown]
# Exercise 1

# %%
a = 2
b = 2.0
c = a

print(f"a: {a}, type: {type(a)}")
print(f"b: {b}, type: {type(b)}")
print(f"c: {c}, type: {type(c)}\n")

print(f"a == b: {a == b} (checks if values are equal)")
print(f"a is b: {a is b} (checks if they are the same object in memory)\n")

print(f"a == c: {a == c} (checks if values are equal)")
print(f"a is c: {a is c} (checks if they are the same object in memory)")
# Out:
# a: 2, type: <class 'int'>
# b: 2.0, type: <class 'float'>
# c: 2, type: <class 'int'>
#
# a == b: True (checks if values are equal)
# a is b: False (checks if they are the same object in memory)
#
# a == c: True (checks if values are equal)
# a is c: True (checks if they are the same object in memory)

# %% [markdown]
# CHALLENGE

# %% [markdown]
# Challenge 1

# %%
total = 0
count = 0
while True:
    num_input = input('Enter a number: ')
    if num_input.lower() == 'done':
        break
    try:
        num = float(num_input)
        total += num
        count += 1
    except ValueError:
        print('Invalid input')

if count > 0:
    average = total / count
    print(f'{total} {count} {average}')
else:
    print('No numbers were entered.')
# Out:
# Enter a number: 55
# Enter a number: 25
# Enter a number: done
# 80.0 2 40.0

# %%
largest = None
smallest = None

while True:
    num_input = input('Enter a number: ')
    if num_input.lower() == 'done':
        break
    try:
        num = float(num_input)

        if largest is None or num > largest:
            largest = num
        if smallest is None or num < smallest:
            smallest = num

    except ValueError:
        print('Invalid input')

if largest is not None and smallest is not None:
    print(f'Maximum: {largest}')
    print(f'Minimum: {smallest}')
else:
    print('No numbers were entered.')
# Out:
# Enter a number: 55
# Enter a number: 93
# Enter a number: done
# Maximum: 93.0
# Minimum: 55.0

# %% [markdown]
# Challenge 2
