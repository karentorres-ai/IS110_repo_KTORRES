# %% [markdown]
# CHAPTER2

# %% [markdown]
# Exercise 1

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: karen
# Hello karen

# %% [markdown]
# #### Exercise 2

# %%
hours = float(input('Enter Hours: '))
rate = float(input('Enter Rate: '))
pay = hours * rate
print('Pay:', pay)
# Out:
# Enter Hours: 5
# Enter Rate: 5
# Pay: 25.0

# %% [markdown]
# #### Exercise 3

# %%
width = 17
height = 12.0

print(f"width//2: Value = {width//2}, Type = {type(width//2)}")
print(f"width/2.0: Value = {width/2.0}, Type = {type(width/2.0)}")
print(f"height/3: Value = {height/3}, Type = {type(height/3)}")
print(f"1 + 2 * 5: Value = {1 + 2 * 5}, Type = {type(1 + 2 * 5)}")
# Out:
# width//2: Value = 8, Type = <class 'int'>
# width/2.0: Value = 8.5, Type = <class 'float'>
# height/3: Value = 4.0, Type = <class 'float'>
# 1 + 2 * 5: Value = 11, Type = <class 'int'>

# %% [markdown]
# Exercise 4

# %%
num_str = input('Enter a number: ')
num = float(num_str)
square = num * num
print(f'The square of {num} is {square}')
# Out:
# Enter a number: 5
# The square of 5.0 is 25.0

# %% [markdown]
# Challenge

# %%
celsius_str = input('Enter Celsius temperature: ')
celsius = float(celsius_str)
fahrenheit = (celsius * 9/5) + 32
print(f'The Fahrenheit temperature is {fahrenheit}')
# Out:
# Enter Celsius temperature: 55
# The Fahrenheit temperature is 131.0
